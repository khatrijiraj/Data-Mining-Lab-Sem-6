# %% [markdown]
# <h1>Name:- Raj Khatri<br>
# Roll Number:- AC-1235<br>
# Subject:- Data Mining<br>
# Semester:- 6<br>
# Practical - 4</h1>

# %% [markdown]
# The dataset is groceries.csv

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori

# %%
grocery_df = pd.read_csv("groceries.csv")

# %%
grocery_df
# Out:
#                                                  Items
# 0    citrus fruit,semi-finished bread,margarine,rea...
# 1                         tropical fruit,yogurt,coffee
# 2                                           whole milk
# 3          pip fruit,yogurt,cream cheese ,meat spreads
# 4    other vegetables,whole milk,condensed milk,lon...
# ..                                                 ...
# 695       pork,UHT-milk,bottled water,soda,canned beer
# 696  other vegetables,curd,yogurt,curd cheese,marga...
# 697  rolls/buns,soda,fruit/vegetable juice,canned b...
# 698  frankfurter,pip fruit,whole milk,rolls/buns,ro...
# 699   yogurt,hygiene articles,newspapers,shopping bags
#
# [700 rows x 1 columns]

# %%
grocery_df.shape
# Out:
# (700, 1)

# %%
items_list = grocery_df['Items'].str.split(',').values

# %%
items_list.tolist()
# Out:
# [['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'],
#  ['tropical fruit', 'yogurt', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese ', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'],
#  ['rolls/buns'],
#  ['other vegetables',
#   'UHT-milk',
#   'rolls/buns',
#   'bottled beer',
#   'liquor (appetizer)'],
#  ['pot plants'],
#  ['whole milk', 'cereals'],
#  ['tropical fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'chocolate'],
#  ['citrus fruit',
#   'tropical fruit',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'flour',
#   'bottled water',
#   'dishes'],
#  ['beef'],
#  ['frankfurter', 'rolls/buns', 'soda'],
#  ['chicken', 'tropical fruit'],
#  ['butter', 'sugar', 'fruit/vegetable juice', 'newspapers'],
#  ['fruit/vegetable juice'],
# ...

# %%
from mlxtend.preprocessing import TransactionEncoder
encoded = TransactionEncoder()
encoded_array = encoded .fit_transform(items_list)
encoded_array
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False,  True, False],
#        [False, False, False, ...,  True, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ...,  True, False, False],
#        [False, False, False, ..., False,  True, False]])

# %%
arr_to_df = pd.DataFrame(encoded_array, columns=encoded.columns_)

# %% [markdown]
# Minimum support is taken as 1% and threshold as 75%

# %%
frequent_itemsets = apriori(arr_to_df, min_support=0.01, use_colnames=True)
print(frequent_itemsets)
# Out:
#       support                                       itemsets
# 0    0.020000                                     (UHT-milk)
# 1    0.011429                                (baking powder)
# 2    0.060000                                         (beef)
# 3    0.040000                                      (berries)
# 4    0.031429                                    (beverages)
# ..        ...                                            ...
# 309  0.012857  (tropical fruit, whole milk, root vegetables)
# 310  0.010000          (whole milk, yogurt, root vegetables)
# 311  0.011429                  (sausage, whole milk, yogurt)
# 312  0.011429                     (whole milk, soda, yogurt)
# 313  0.012857           (tropical fruit, whole milk, yogurt)
#
# [314 rows x 2 columns]

# %%
from mlxtend.frequent_patterns import association_rules
rules = association_rules(
    frequent_itemsets, metric="confidence", min_threshold=0.75)
rules
# Out:
#                        antecedents   consequents  antecedent support  \
# 0                        (cereals)  (whole milk)            0.011429
# 1                 (frozen dessert)  (whole milk)            0.014286
# 2  (fruit/vegetable juice, yogurt)  (whole milk)            0.017143
# 3          (margarine, rolls/buns)  (whole milk)            0.017143
# 4       (sausage, root vegetables)  (rolls/buns)            0.012857
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.251429  0.010000    0.875000  3.480114  0.007127    5.988571
# 1            0.251429  0.011429    0.800000  3.181818  0.007837    3.742857
# 2            0.251429  0.014286    0.833333  3.314394  0.009976    4.491429
# 3            0.251429  0.012857    0.750000  2.982955  0.008547    2.994286
# 4            0.218571  0.010000    0.777778  3.558460  0.007190    3.516429
